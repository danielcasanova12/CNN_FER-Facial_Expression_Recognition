# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile

# %%
# Ler o arquivo CSV
data_path = './DataSet/fer2013/fer2013.csv'
data = pd.read_csv(data_path)

# Obter a lista de pixels
pixels = data['pixels'].tolist()

# %%
def show_image_with_matplotlib(image):
    # Converter a imagem para o formato esperado por Matplotlib
    if len(image.shape) == 2:  # Imagem em escala de cinza
        plt.imshow(image, cmap='gray')
    else:  # Imagem colorida
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # Desativar os eixos
    plt.show()

# %%
rostos = []
amostras = 0
for pixel_sequence in pixels:
  rosto = [int(pixel) for pixel in pixel_sequence.split(' ')]
  rosto = np.asarray(rosto).reshape((48, 48))
  rostos.append(rosto)
  if (amostras < 10):
    show_image_with_matplotlib(rosto)
  amostras += 1

# %%
rostos =  np.asarray(rostos)
rostos.shape
# Out:
# (35887, 48, 48)

# %%
# Adicionar uma dimensão para o canal de cores
rostos = np.expand_dims(rostos, -1)
rostos.shape
# Out:
# (35887, 48, 48, 1)

# %%
#Normalização dos pixels dos rostos
rostos= rostos.astype('float32')
rostos /= 255

# %%
emocoes = pd.get_dummies(data['emotion']).values

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
X_train, X_test, y_train, y_test = train_test_split(rostos, emocoes, test_size=0.1, random_state=42)
_, X_val, _, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
print('numero de imagens treino', len(X_train))
print('numero de imagens teste', len(X_test))
print('numero de imagens validação', len(X_val))
# Out:
# numero de imagens treino 32298
# numero de imagens teste 3589
# numero de imagens validação 3230

# %%
features = 64
classes = 7
epochs = 50
batch_size = 64
largura, altura = 48, 48

model = Sequential()

model.add(Conv2D(features, kernel_size=(3, 3), activation='relu', input_shape=(largura, altura, 1),data_format = 'channels_last' ,kernel_regularizer = l2(0.01)))
model.add(Conv2D(features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5)) #dropout ideal seria cerca de 0.2 porém a implementação original utiliza 0.5

model.add(Conv2D(2*features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(2*features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*features, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
# A cada grupo de camadas, se utiliza o dobro do grupo passado pois as primeiras camadas são para características simples portanto necessitam de poucos filtros
# enquanto as camadas mais profundas detectam caracteristicas mais avançadas e
# sutis
model.add(Flatten())

# Após realizar o flatenning é necessário criar a rede neural densa

model.add(Dense(2*2*2*features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*features, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(classes, activation='softmax'))
model.summary()
# Out:
# c:\Users\daneil\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)              │ (None, 46, 46, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 46, 46, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 46, 46, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 23, 23, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 23, 23, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 23, 23, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 23, 23, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 11, 11, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 11, 11, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 11, 11, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 11, 11, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 11, 11, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 11, 11, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 5, 5, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 5, 5, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 5, 5, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 5, 5, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,905,863 (22.53 MB)
#  Trainable params: 5,902,151 (22.51 MB)
#  Non-trainable params: 3,712 (14.50 KB)

# %%
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2= 0.999, epsilon = 1e-7),
              metrics=['accuracy'])
arquivo = 'modelo_01_expressoes.keras'
arquivo_json = 'modelo_01_expressoes.json'

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1,)
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=8, verbose=1, mode='auto') # Caso não apresente melhorias em 8 épocas encerra o processo de treinamento
checkpointer = ModelCheckpoint(filepath=arquivo, verbose=1, save_best_only=True) # Salva o melhor modelo em um arquivo, evitando que o resultado após as épocas seja um modelo subotimizado

# %%
model_json = model.to_json()
with open(arquivo_json, "w") as json_file:
    json_file.write(model_json)

# %%
hist = model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_val), np.array(y_val)), # Expõe qual base de dados será utilizada para validação
          shuffle=True,
          callbacks=[lr_reducer, early_stopper, checkpointer])
# Out:
# Epoch 1/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.2021 - loss: 2.2747
# Epoch 1: val_loss improved from inf to 1.83382, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 330s 643ms/step - accuracy: 0.2022 - loss: 2.2741 - val_accuracy: 0.2467 - val_loss: 1.8338 - learning_rate: 0.0010
# Epoch 2/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.2409 - loss: 1.8368
# Epoch 2: val_loss improved from 1.83382 to 1.80384, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 317s 627ms/step - accuracy: 0.2409 - loss: 1.8367 - val_accuracy: 0.2480 - val_loss: 1.8038 - learning_rate: 0.0010
# Epoch 3/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - accuracy: 0.2519 - loss: 1.8080
# Epoch 3: val_loss improved from 1.80384 to 1.75834, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 303s 600ms/step - accuracy: 0.2519 - loss: 1.8080 - val_accuracy: 0.2724 - val_loss: 1.7583 - learning_rate: 0.0010
# Epoch 4/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.2839 - loss: 1.7476
# Epoch 4: val_loss did not improve from 1.75834
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 298s 590ms/step - accuracy: 0.2839 - loss: 1.7476 - val_accuracy: 0.2099 - val_loss: 1.7958 - learning_rate: 0.0010
# Epoch 5/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 651ms/step - accuracy: 0.3492 - loss: 1.6336
# Epoch 5: val_loss improved from 1.75834 to 1.75347, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 341s 675ms/step - accuracy: 0.3492 - loss: 1.6336 - val_accuracy: 0.2981 - val_loss: 1.7535 - learning_rate: 0.0010
# Epoch 6/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - accuracy: 0.3991 - loss: 1.5232
# Epoch 6: val_loss did not improve from 1.75347
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 324s 641ms/step - accuracy: 0.3991 - loss: 1.5231 - val_accuracy: 0.2858 - val_loss: 1.7640 - learning_rate: 0.0010
# Epoch 7/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.4225 - loss: 1.4620
# Epoch 7: val_loss improved from 1.75347 to 1.47647, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 312s 617ms/step - accuracy: 0.4225 - loss: 1.4620 - val_accuracy: 0.4158 - val_loss: 1.4765 - learning_rate: 0.0010
# Epoch 8/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.4436 - loss: 1.4236
# Epoch 8: val_loss did not improve from 1.47647
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 323s 639ms/step - accuracy: 0.4436 - loss: 1.4235 - val_accuracy: 0.4356 - val_loss: 1.4956 - learning_rate: 0.0010
# Epoch 9/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.4648 - loss: 1.3752
# Epoch 9: val_loss improved from 1.47647 to 1.22776, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 308s 610ms/step - accuracy: 0.4648 - loss: 1.3752 - val_accuracy: 0.5359 - val_loss: 1.2278 - learning_rate: 0.0010
# Epoch 10/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - accuracy: 0.4807 - loss: 1.3458
# Epoch 10: val_loss improved from 1.22776 to 1.19197, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 312s 619ms/step - accuracy: 0.4807 - loss: 1.3457 - val_accuracy: 0.5406 - val_loss: 1.1920 - learning_rate: 0.0010
# Epoch 11/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - accuracy: 0.5083 - loss: 1.3049
# Epoch 11: val_loss improved from 1.19197 to 1.17464, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 320s 634ms/step - accuracy: 0.5083 - loss: 1.3049 - val_accuracy: 0.5734 - val_loss: 1.1746 - learning_rate: 0.0010
# Epoch 12/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.5172 - loss: 1.2664
# Epoch 12: val_loss improved from 1.17464 to 1.16630, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 312s 619ms/step - accuracy: 0.5172 - loss: 1.2664 - val_accuracy: 0.5755 - val_loss: 1.1663 - learning_rate: 0.0010
# Epoch 13/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.5330 - loss: 1.2484
# Epoch 13: val_loss improved from 1.16630 to 1.10664, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 297s 588ms/step - accuracy: 0.5330 - loss: 1.2484 - val_accuracy: 0.5830 - val_loss: 1.1066 - learning_rate: 0.0010
# Epoch 14/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.5447 - loss: 1.2195
# Epoch 14: val_loss did not improve from 1.10664
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 280s 555ms/step - accuracy: 0.5447 - loss: 1.2195 - val_accuracy: 0.5740 - val_loss: 1.1444 - learning_rate: 0.0010
# Epoch 15/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.5626 - loss: 1.1930
# Epoch 15: val_loss did not improve from 1.10664
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 301s 597ms/step - accuracy: 0.5626 - loss: 1.1930 - val_accuracy: 0.5009 - val_loss: 1.3382 - learning_rate: 0.0010
# Epoch 16/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.5732 - loss: 1.1489
# Epoch 16: val_loss improved from 1.10664 to 0.97670, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 303s 600ms/step - accuracy: 0.5732 - loss: 1.1490 - val_accuracy: 0.6421 - val_loss: 0.9767 - learning_rate: 0.0010
# Epoch 17/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.5854 - loss: 1.1305
# Epoch 17: val_loss did not improve from 0.97670
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 342s 677ms/step - accuracy: 0.5854 - loss: 1.1305 - val_accuracy: 0.5059 - val_loss: 1.2793 - learning_rate: 0.0010
# Epoch 18/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.5910 - loss: 1.1129
# Epoch 18: val_loss improved from 0.97670 to 0.93471, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 341s 676ms/step - accuracy: 0.5910 - loss: 1.1129 - val_accuracy: 0.6554 - val_loss: 0.9347 - learning_rate: 0.0010
# Epoch 19/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.6054 - loss: 1.0765
# Epoch 19: val_loss did not improve from 0.93471
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 339s 672ms/step - accuracy: 0.6054 - loss: 1.0765 - val_accuracy: 0.6467 - val_loss: 0.9713 - learning_rate: 0.0010
# Epoch 20/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.6161 - loss: 1.0678
# Epoch 20: val_loss improved from 0.93471 to 0.87251, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 355s 703ms/step - accuracy: 0.6161 - loss: 1.0678 - val_accuracy: 0.6867 - val_loss: 0.8725 - learning_rate: 0.0010
# Epoch 21/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.6268 - loss: 1.0332
# Epoch 21: val_loss did not improve from 0.87251
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 355s 702ms/step - accuracy: 0.6268 - loss: 1.0332 - val_accuracy: 0.6700 - val_loss: 0.8793 - learning_rate: 0.0010
# Epoch 22/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.6315 - loss: 1.0240
# Epoch 22: val_loss improved from 0.87251 to 0.84679, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 359s 710ms/step - accuracy: 0.6315 - loss: 1.0240 - val_accuracy: 0.6985 - val_loss: 0.8468 - learning_rate: 0.0010
# Epoch 23/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.6377 - loss: 0.9983
# Epoch 23: val_loss did not improve from 0.84679
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 379s 750ms/step - accuracy: 0.6377 - loss: 0.9983 - val_accuracy: 0.6793 - val_loss: 0.8631 - learning_rate: 0.0010
# Epoch 24/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 724ms/step - accuracy: 0.6493 - loss: 0.9701
# Epoch 24: val_loss did not improve from 0.84679
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 374s 740ms/step - accuracy: 0.6492 - loss: 0.9701 - val_accuracy: 0.6641 - val_loss: 0.8930 - learning_rate: 0.0010
# Epoch 25/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.6518 - loss: 0.9586
# Epoch 25: val_loss improved from 0.84679 to 0.83777, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 371s 734ms/step - accuracy: 0.6518 - loss: 0.9587 - val_accuracy: 0.6947 - val_loss: 0.8378 - learning_rate: 0.0010
# Epoch 26/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.6593 - loss: 0.9469
# Epoch 26: val_loss improved from 0.83777 to 0.73649, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 355s 703ms/step - accuracy: 0.6593 - loss: 0.9469 - val_accuracy: 0.7272 - val_loss: 0.7365 - learning_rate: 0.0010
# Epoch 27/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.6614 - loss: 0.9432
# Epoch 27: val_loss improved from 0.73649 to 0.68054, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 330s 653ms/step - accuracy: 0.6614 - loss: 0.9432 - val_accuracy: 0.7505 - val_loss: 0.6805 - learning_rate: 0.0010
# Epoch 28/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.6746 - loss: 0.9043
# Epoch 28: val_loss did not improve from 0.68054
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 351s 695ms/step - accuracy: 0.6746 - loss: 0.9043 - val_accuracy: 0.7378 - val_loss: 0.7307 - learning_rate: 0.0010
# Epoch 29/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.6749 - loss: 0.8948
# Epoch 29: val_loss did not improve from 0.68054
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 346s 686ms/step - accuracy: 0.6749 - loss: 0.8948 - val_accuracy: 0.7486 - val_loss: 0.6975 - learning_rate: 0.0010
# Epoch 30/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.6851 - loss: 0.8793
# Epoch 30: val_loss improved from 0.68054 to 0.66954, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 364s 720ms/step - accuracy: 0.6851 - loss: 0.8793 - val_accuracy: 0.7548 - val_loss: 0.6695 - learning_rate: 0.0010
# Epoch 31/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.6928 - loss: 0.8643
# Epoch 31: val_loss improved from 0.66954 to 0.64506, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 324s 641ms/step - accuracy: 0.6928 - loss: 0.8643 - val_accuracy: 0.7650 - val_loss: 0.6451 - learning_rate: 0.0010
# Epoch 32/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 670ms/step - accuracy: 0.6970 - loss: 0.8489
# Epoch 32: val_loss improved from 0.64506 to 0.61417, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 348s 689ms/step - accuracy: 0.6970 - loss: 0.8489 - val_accuracy: 0.7786 - val_loss: 0.6142 - learning_rate: 0.0010
# Epoch 33/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.7018 - loss: 0.8240
# Epoch 33: val_loss did not improve from 0.61417
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 318s 630ms/step - accuracy: 0.7017 - loss: 0.8240 - val_accuracy: 0.7675 - val_loss: 0.6501 - learning_rate: 0.0010
# Epoch 34/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.7081 - loss: 0.8146
# Epoch 34: val_loss improved from 0.61417 to 0.57397, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 345s 683ms/step - accuracy: 0.7081 - loss: 0.8146 - val_accuracy: 0.7972 - val_loss: 0.5740 - learning_rate: 0.0010
# Epoch 35/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.7185 - loss: 0.7925
# Epoch 35: val_loss improved from 0.57397 to 0.52866, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 314s 623ms/step - accuracy: 0.7185 - loss: 0.7925 - val_accuracy: 0.8121 - val_loss: 0.5287 - learning_rate: 0.0010
# Epoch 36/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.7193 - loss: 0.7834
# Epoch 36: val_loss did not improve from 0.52866
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 346s 685ms/step - accuracy: 0.7193 - loss: 0.7834 - val_accuracy: 0.7882 - val_loss: 0.5821 - learning_rate: 0.0010
# Epoch 37/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.7195 - loss: 0.7753
# Epoch 37: val_loss improved from 0.52866 to 0.51820, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 362s 716ms/step - accuracy: 0.7195 - loss: 0.7753 - val_accuracy: 0.8189 - val_loss: 0.5182 - learning_rate: 0.0010
# Epoch 38/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - accuracy: 0.7280 - loss: 0.7599
# Epoch 38: val_loss did not improve from 0.51820
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 325s 644ms/step - accuracy: 0.7280 - loss: 0.7600 - val_accuracy: 0.8220 - val_loss: 0.5306 - learning_rate: 0.0010
# Epoch 39/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.7363 - loss: 0.7434
# Epoch 39: val_loss improved from 0.51820 to 0.51186, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 417s 826ms/step - accuracy: 0.7363 - loss: 0.7435 - val_accuracy: 0.8142 - val_loss: 0.5119 - learning_rate: 0.0010
# Epoch 40/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.7375 - loss: 0.7342
# Epoch 40: val_loss improved from 0.51186 to 0.48600, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 425s 842ms/step - accuracy: 0.7375 - loss: 0.7343 - val_accuracy: 0.8180 - val_loss: 0.4860 - learning_rate: 0.0010
# Epoch 41/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 779ms/step - accuracy: 0.7490 - loss: 0.7160
# Epoch 41: val_loss did not improve from 0.48600
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 403s 798ms/step - accuracy: 0.7490 - loss: 0.7160 - val_accuracy: 0.7867 - val_loss: 0.5923 - learning_rate: 0.0010
# Epoch 42/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.7470 - loss: 0.7102
# Epoch 42: val_loss did not improve from 0.48600
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 427s 845ms/step - accuracy: 0.7470 - loss: 0.7102 - val_accuracy: 0.8266 - val_loss: 0.5049 - learning_rate: 0.0010
# Epoch 43/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7529 - loss: 0.6995
# Epoch 43: val_loss improved from 0.48600 to 0.45138, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 556s 1s/step - accuracy: 0.7529 - loss: 0.6995 - val_accuracy: 0.8492 - val_loss: 0.4514 - learning_rate: 0.0010
# Epoch 44/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7613 - loss: 0.6784
# Epoch 44: val_loss did not improve from 0.45138
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 523s 1s/step - accuracy: 0.7613 - loss: 0.6784 - val_accuracy: 0.8291 - val_loss: 0.4949 - learning_rate: 0.0010
# Epoch 45/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7642 - loss: 0.6615
# Epoch 45: val_loss improved from 0.45138 to 0.44792, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 760s 2s/step - accuracy: 0.7642 - loss: 0.6615 - val_accuracy: 0.8409 - val_loss: 0.4479 - learning_rate: 0.0010
# Epoch 46/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7685 - loss: 0.6581
# Epoch 46: val_loss did not improve from 0.44792
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 821s 2s/step - accuracy: 0.7685 - loss: 0.6581 - val_accuracy: 0.8053 - val_loss: 0.4997 - learning_rate: 0.0010
# Epoch 47/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7708 - loss: 0.6536
# Epoch 47: val_loss improved from 0.44792 to 0.41109, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 786s 2s/step - accuracy: 0.7708 - loss: 0.6537 - val_accuracy: 0.8554 - val_loss: 0.4111 - learning_rate: 0.0010
# Epoch 48/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7747 - loss: 0.6371
# Epoch 48: val_loss improved from 0.41109 to 0.39890, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 803s 2s/step - accuracy: 0.7747 - loss: 0.6372 - val_accuracy: 0.8610 - val_loss: 0.3989 - learning_rate: 0.0010
# Epoch 49/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7826 - loss: 0.6273
# Epoch 49: val_loss improved from 0.39890 to 0.37694, saving model to modelo_01_expressoes.keras
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 798s 2s/step - accuracy: 0.7825 - loss: 0.6274 - val_accuracy: 0.8752 - val_loss: 0.3769 - learning_rate: 0.0010
# Epoch 50/50
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7780 - loss: 0.6203
# Epoch 50: val_loss did not improve from 0.37694
# 505/505 ━━━━━━━━━━━━━━━━━━━━ 828s 2s/step - accuracy: 0.7780 - loss: 0.6204 - val_accuracy: 0.8663 - val_loss: 0.3939 - learning_rate: 0.0010
